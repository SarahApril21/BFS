# %%
hub_gejala = {
    'G7': ['G17'],
    'G17': ['G18', 'G14', 'G11', 'G9', 'G5'],
    'G18': ['G21', 'G10'],
    'G14': ['G21', 'G10', 'G8'],
    'G11': ['G21', 'G10', 'G8'],
    'G9': ['G21', 'G8'],
    'G5': ['G10', 'G8'],
    'G21': ['G19', 'G1'],
    'G10': ['G12', 'G6'],
    'G8': ['G12', 'G4'],
    'G19': ['G22'],
    'G1': ['G2'],
    'G12': ['G13'],
    'G6': ['G26'],
    'G4': ['G15'],
    'G22': [],
    'G2': ['G3'],
    'G13': ['G20'],
    'G26': [],
    'G15': ['G16'],
    'G3': ['G23'],
    'G20': ['G25'],
    'G16': [],
    'G23': ['G24'],
    'G25': [],
    'G24': []
}


def gejala_awal(hub_gejala, gejala_awal):
    queue = [gejala_awal]
    visited = {gejala_awal}
    gejala = set()
   
    while queue:
        m = queue.pop(0)
        y = hub_gejala[m]
       
        for i in y:
            if i not in visited:
                isi = input(f"Is symptom {i} present? (yes/no): ")
                if isi.lower() == "yes":
                    gejala.add(i)
                visited.add(i)
                queue.append(i)
   
    proses(gejala)


def proses(a):
    penyakit = []
    penyakit_1 = {"G9", "G11", "G17", "G18", "G19", "G21", "G22"}
    penyakit_2 = {"G1", "G2", "G3", "G9", "G14", "G17", "G18", "G21", "G23", "G24"}
    penyakit_3 = {"G5", "G8", "G10", "G11", "G12", "G13", "G14", "G17", "G20", "G25"}
    penyakit_4 = {"G4", "G5", "G8", "G9", "G15", "G16", "G17"}
    penyakit_5 = {"G5", "G6", "G11", "G10", "G6", "G26"}
   
    if penyakit_1.issubset(a):
        penyakit.append("P1")
    elif penyakit_2.issubset(a):
        penyakit.append("P2")
    elif penyakit_3.issubset(a):
        penyakit.append("P3")
    elif penyakit_4.issubset(a):
        penyakit.append("P4")
    elif penyakit_5.issubset(a):
        penyakit.append("P5")
   
    print("Sapi didiagnosa memiliki penyakit:", penyakit)


gejala_awal(hub_gejala, 'G7')

import tkinter as tk
from tkinter import messagebox


hub_gejala = {
    'Lesu': ['Demam tinggi (hingga lebih dari 40 derajat C)'],
    'Demam tinggi (hingga lebih dari 40 derajat C)': ['Penurunan produksi susu pada sapi perah', 'Keluar air liur berlebihan', 'Keluar cairan pada hidung dan mata (ingusan)', 'Penurunan nafsu makan', 'Adanya perilaku berjalan menjadi sempoyongan'],
    'Penurunan produksi susu pada sapi perah': ['Terdapat lesi pada kulit', 'Kesulitan bernapas'],
    'Keluar air liur berlebihan': ['Terdapat lesi pada kulit', 'Kesulitan bernapas', 'Kondisi menjadi lebih kurus'],
    'Keluar cairan pada hidung dan mata (ingusan)': ['Terdapat lesi pada kulit', 'Kesulitan bernapas', 'Kondisi menjadi lebih kurus'],
    'Penurunan nafsu makan': ['Terdapat lesi pada kulit', 'Kondisi menjadi lebih kurus'],
    'Adanya perilaku berjalan menjadi sempoyongan': ['Kesulitan bernapas', 'Kondisi menjadi lebih kurus'],
    'Terdapat lesi pada kulit': ['Pembengkakan pada kelenjar getah bening (limfonodus)', 'Adanya perilaku sering menggeretakkan gigi'],
    'Kesulitan bernapas': ['Hidung tersumbat oleh kerak', 'Adanya kekakuan anggota gerak'],
    'Kondisi menjadi lebih kurus': ['Hidung tersumbat oleh kerak', 'Kejang'],
    'Pembengkakan pada kelenjar getah bening (limfonodus)': ['Bentuk lesi pada kulit berupa benjolan'],
    'Adanya perilaku sering menggeretakkan gigi': ['Adanya perilaku sering menggosokkan mulut'],
    'Hidung tersumbat oleh kerak': ['Moncong menjadi kering dan pecah-pecah terisi oleh eksudat (nanah)'],
    'Adanya kekakuan anggota gerak': ['Busung pada bagian bawah rahang dan kaki'],
    'Kejang': ['Keluar getah radang dari hidung dan mata'],
    'Bentuk lesi pada kulit berupa benjolan': [],
    'Adanya perilaku sering menggosokkan mulut': ['Adanya perilaku sering menendangkan kaki'],
    'Moncong menjadi kering dan pecah-pecah terisi oleh eksudat (nanah)': ['Pembengkakan pada kelenjar limfe luar tubuh'],
    'Busung pada bagian bawah rahang dan kaki': [],
    'Keluar getah radang dari hidung dan mata': ['Bulu menjadi rontok'],
    'Adanya perilaku sering menendangkan kaki': ['Bentuk lesi pada kulit berupa lepuh-lepuh'],
    'Pembengkakan pada kelenjar limfe luar tubuh': ['Terdapat penebalan dan pengelupasan kulit'],
    'Bulu menjadi rontok': [],
    'Bentuk lesi pada kulit berupa lepuh-lepuh': ['Terdapat luka pada kuku hingga kuku lepas'],
    'Terdapat penebalan dan pengelupasan kulit': [],
    'Terdapat luka pada kuku hingga kuku lepas': []
}


def gejala_awal(hub_gejala, gejala_awal):
    queue = [gejala_awal]
    visited = {gejala_awal}
    gejala = set()
   
    while queue:
        m = queue.pop(0)
        y = hub_gejala[m]
       
        for i in y:
            if i not in visited:
                isi = messagebox.askquestion("Pertanyaan Diagnosis Penyakit Sapi", f"Apakah Sapi anda memiliki gejala {i} ini?")
                if isi == "yes":
                    gejala.add(i)
                visited.add(i)
                queue.append(i)
   
    proses(gejala)


def proses(a):
    penyakit = []
    penyakit_1 = {"Penurunan nafsu makan", "Keluar cairan pada hidung dan mata (ingusan)",
                  "Demam tinggi (hingga lebih dari 40 derajat C)", "Penurunan produksi susu pada sapi perah",
                  "Pembengkakan pada kelenjar getah bening (limfonodus)", "Terdapat lesi pada kulit", "Bentuk lesi pada kulit berupa benjolan"}
    penyakit_2 = {"Adanya perilaku sering menggeretakkan gigi", "Adanya perilaku sering menggosokkan mulut",
                  "Adanya perilaku sering menendangkan kaki", "Penurunan nafsu makan",
                  "Keluar air liur berlebihan", "Demam tinggi (hingga lebih dari 40 derajat C)", "Penurunan produksi susu pada sapi perah",
                  "Terdapat lesi pada kulit", "Bentuk lesi pada kulit berupa lepuh-lepuh", "Terdapat luka pada kuku hingga kuku lepas"}
    penyakit_3 = {"Adanya perilaku berjalan menjadi sempoyongan", "Kondisi menjadi lebih kurus", "Kesulitan bernapas",
                  "Keluar cairan pada hidung dan mata (ingusan)", "Hidung tersumbat oleh kerak",
                  "Moncong menjadi kering dan pecah-pecah terisi oleh eksudat (nanah)", "Keluar air liur berlebihan",
                  "Demam tinggi (hingga lebih dari 40 derajat C)", "Pembengkakan pada kelenjar limfe luar tubuh",
                  "Terdapat penebalan dan pengelupasan kulit"}
    penyakit_4 = {"Kejang", "Adanya perilaku berjalan menjadi sempoyongan", "Kondisi menjadi lebih kurus", "Penurunan nafsu makan",
                  "Keluar getah radang dari hidung dan mata", "Bulu menjadi rontok", "Demam tinggi (hingga lebih dari 40 derajat C)"}
    penyakit_5 = {"Adanya perilaku berjalan menjadi sempoyongan", "Adanya kekakuan anggota gerak", "Keluar cairan pada hidung dan mata (ingusan)",
                  "Kesulitan bernapas", "Penurunan produksi susu pada sapi perah", "Busung pada bagian bawah rahang dan kaki"}
   
    if penyakit_1.issubset(a):
        penyakit.append("Lumpy Skin Disease (LSD)")
    if penyakit_2.issubset(a):
        penyakit.append("Foot and Mouth Disease (FMD) / Apthtae Epizooticae / Penyakit Mulut dan Kuku (PMK)")
    if penyakit_3.issubset(a):
        penyakit.append("Malignant Ctrrahal Fever (MCF) Disease / Penyakit Ingusan")
    if penyakit_4.issubset(a):
        penyakit.append("Trypanosomiasis Disease / Surra")
    if penyakit_5.issubset(a):
        penyakit.append("Bovine Epheral Fever (BEF) / Demam Tiga Hari")
    if not penyakit:
        penyakit.append('tidak diketahui, karena gejala yang dialami sapi Anda tidak terdefinisikan dalam program')
   
    messagebox.showinfo("Hasil Diagnosis", f"Sapi Anda didiagnosa memiliki penyakit: {penyakit}")


# GUI using Tkinter
def main():
    root = tk.Tk()
    root.title("Diagnosis Penyakit Sapi")
   
    def start_diagnosis():
        gejala_awal(hub_gejala, 'Lesu')
   
    def submit():
        JenisKelamin = JenisKelaminSapiEntry.get()
        print('Jenis kelamin adalah ' + JenisKelamin)
        UmurSapi = UmurSapiEntry.get()
        print('Umur Sapi yaitu ' + UmurSapi + ' tahun')
 
    JenisKelaminSapiLabel = tk.Label(root, text="Jenis Kelamin Sapi (Jantan/Betina): ")
    JenisKelaminSapiLabel.pack()
    JenisKelaminSapiEntry = tk.Entry(root)
    JenisKelaminSapiEntry.pack()


    UmurSapiLabel = tk.Label(root, text="Umur Sapi (tahun): ")
    UmurSapiLabel.pack()
    UmurSapiEntry = tk.Entry(root)
    UmurSapiEntry.pack()


    submitbutton = tk.Button(root, text='Submit', command=submit)
    submitbutton.pack()


    start_button = tk.Button(root, text="Start Diagnosis", command=start_diagnosis)
    start_button.pack(pady=10)


    root.mainloop()


if __name__== '__main__':
    main()
# Out:
# Is symptom G17 present? (yes/no): yes
# Is symptom G18 present? (yes/no): yes
# Is symptom G14 present? (yes/no): no
# Is symptom G11 present? (yes/no): yes
# Is symptom G9 present? (yes/no): yes
# Is symptom G5 present? (yes/no): no
# Is symptom G21 present? (yes/no): yes
# Is symptom G10 present? (yes/no): no
# Is symptom G8 present? (yes/no): nno
# Is symptom G19 present? (yes/no): yes
# Is symptom G1 present? (yes/no): no
# Is symptom G12 present? (yes/no): no
# Is symptom G6 present? (yes/no): no
# Is symptom G4 present? (yes/no): no
# Is symptom G22 present? (yes/no): yes
# Is symptom G2 present? (yes/no): no
# Is symptom G13 present? (yes/no): no
# Is symptom G26 present? (yes/no): no
# Is symptom G15 present? (yes/no): no
# Is symptom G3 present? (yes/no): no
# Is symptom G20 present? (yes/no): no
# Is symptom G16 present? (yes/no): no
# Is symptom G23 present? (yes/no): no
# Is symptom G25 present? (yes/no): no
# Is symptom G24 present? (yes/no): no
# ...
